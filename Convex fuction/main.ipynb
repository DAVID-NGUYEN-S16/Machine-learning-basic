# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import random

# %%
len(x[:, 1])
# Out:
# 50

# %%
random.uniform(10, 100)
# Out:
# 56.34216813770604

# %%
import matplotlib.pyplot as plt

# %%
k = x[:, 0]
k
# Out:
# array([0.68244481, 0.39122287, 0.70848207, 0.15544116, 0.63396541,
#        0.86229069, 0.34923052, 0.65619649, 0.50129394, 0.22854718,
#        0.57935729, 0.85345284, 0.24476626, 0.11986454, 0.81481267,
#        0.77213789, 0.37214801, 0.58159335, 0.37270324, 0.54715259,
#        0.15937398, 0.07270542, 0.86845312, 0.63666506, 0.27062571,
#        0.07700385, 0.88061785, 0.94412687, 0.88093599, 0.49786337,
#        0.41853182, 0.24572931, 0.33594535, 0.34641755, 0.55740363,
#        0.69516891, 0.87481053, 0.55570901, 0.7852329 , 0.44119265,
#        0.88359437, 0.06390147, 0.34905107, 0.99041707, 0.6732525 ,
#        0.0443027 , 0.93943096, 0.52365521, 0.45898546, 0.58726945])

# %%
x[0:2, 0]
# Out:
# array([0.68244481, 0.39122287])

# %% [markdown]
# ## PROVE $x_{\theta} = \theta x_1 + (1-\theta)x_2$

# %%
plt.scatter(x[:, 0], x[:, 1])
plt.scatter(x=x[0:2, 0], y=x[0:2, 1], c='red')

# %%
x
# Out:
# array([[6.82444813e-01, 5.93083548e-01],
#        [3.91222873e-01, 6.25498401e-01],
#        [7.08482070e-01, 9.00701925e-01],
#        [1.55441164e-01, 8.86403307e-02],
#        [6.33965415e-01, 6.85029947e-01],
#        [8.62290690e-01, 8.00920671e-01],
#        [3.49230522e-01, 3.56605742e-01],
#        [6.56196490e-01, 8.80798989e-01],
#        [5.01293943e-01, 1.09580180e-01],
#        [2.28547178e-01, 7.76588620e-01],
#        [5.79357291e-01, 4.68266099e-01],
#        [8.53452842e-01, 5.03915583e-01],
#        [2.44766259e-01, 5.01002105e-02],
#        [1.19864542e-01, 5.43639224e-01],
#        [8.14812666e-01, 8.44187117e-01],
#        [7.72137886e-01, 4.55138352e-04],
#        [3.72148013e-01, 4.60257351e-01],
#        [5.81593346e-01, 6.00139543e-02],
#        [3.72703235e-01, 2.26485886e-01],
#        [5.47152586e-01, 5.94155614e-01],
#        [1.59373980e-01, 6.68092175e-01],
#        [7.27054181e-02, 9.79270358e-01],
#        [8.68453125e-01, 7.51425806e-01],
# ...

# %%
theta = 0.01
x1 = x[0]
x2 = x[1]
x0 = []
for p in range(10):
    if theta == 1: break
    x0_sub = theta*x1 + (1 - theta)*x2
    x0.append(x0_sub)
    theta+=0.1
x0
# Out:
# [array([0.39413509, 0.62517425]),
#  array([0.42325729, 0.62193277]),
#  array([0.45237948, 0.61869128]),
#  array([0.48150167, 0.6154498 ]),
#  array([0.51062387, 0.61220831]),
#  array([0.53974606, 0.60896683]),
#  array([0.56886826, 0.60572534]),
#  array([0.59799045, 0.60248386]),
#  array([0.62711264, 0.59924237]),
#  array([0.65623484, 0.59600088])]

# %%
x0 = np.array(x0)
x0
# Out:
# array([[0.39413509, 0.62517425],
#        [0.42325729, 0.62193277],
#        [0.45237948, 0.61869128],
#        [0.48150167, 0.6154498 ],
#        [0.51062387, 0.61220831],
#        [0.53974606, 0.60896683],
#        [0.56886826, 0.60572534],
#        [0.59799045, 0.60248386],
#        [0.62711264, 0.59924237],
#        [0.65623484, 0.59600088]])

# %%
x0[:, 1]
# Out:
# array([0.62517425, 0.62193277, 0.61869128, 0.6154498 , 0.61220831,
#        0.60896683, 0.60572534, 0.60248386, 0.59924237, 0.59600088])

# %%
plt.scatter(x[:, 0], x[:, 1])
plt.scatter(x=x[0:2, 0], y=x[0:2, 1], c='red')
plt.scatter(x=x0[:, 0], y=x0[:, 1], c='b')

# %%
x0[0:2, 1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 x0[0:2, 1]
#
# TypeError: list indices must be integers or slices, not tuple
